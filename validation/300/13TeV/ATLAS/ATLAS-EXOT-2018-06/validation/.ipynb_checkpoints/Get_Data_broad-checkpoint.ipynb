# %%
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
import sys, re, os
import numpy as np
import pandas as pd
import glob,imp
from pandas import json_normalize
import pyslha
sys.path.append('../../smodels')
from smodels.particlesLoader import getParticlesFromSLHA
pd.options.mode.chained_assignment = None #Disable copy warnings
from smodels.experiment.databaseObj import Database
from smodels.base.model import Model
from smodels.decomposition import decomposer
from smodels.matching.theoryPrediction import theoryPredictionsFor
from smodels.base.physicsUnits import fb, GeV
#from smodels.share.models.ppZpjj import BSMList
from smodels.share.models.SMparticles import SMList
from smodels.base.smodelsLogging import setLogLevel
from smodels.base import runtime
from smodels.experiment.expSMS import ExpSMS
from smodels.experiment.defaultFinalStates import finalStates
setLogLevel("info")
#runtime.modelFile = 'smodels.share.models.ppZpjj'
# !runSModelS.py -V
# Out:
# /tmp/ipykernel_6727/1150286002.py:6: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import glob,imp
# 3.0.0-beta

# %%
BSMlist = getParticlesFromSLHA('TRV1_slha/run_01_mzp_1000.1_mx_450.1_nevents_70000.slha')
model = Model(BSMparticles=BSMlist, SMparticles=SMList)
print(BSMlist)
# Out:
# [gha, gha~, ghz, ghz~, ghwp, ghwp~, ghwm, ghwm~, ghg, ghg~, xr, xc, xc~, xd, xd~, y1]

# %%
slhaFolder = 'TRV1_slha'
resultsFolder = 'TRV1jj_results'
File = 'parameters.ini'
# !chmod -R +rwx {slhaFolder}

# %%
# !runSModelS.py -p {File} -f {slhaFolder} -o {resultsFolder}
# Out:
# INFO in databaseObj.loadDatabase() in 466: Creating binary database
# INFO in databaseObj.loadDatabase() in 467: (this may take a few minutes, but it's done only once!)
# INFO in databaseObj.loadTextDatabase() in 481: Parsing text database at /home/yoxara/smodels-database/
# Traceback (most recent call last):
#   File "/home/yoxara/smodels/runSModelS.py", line 4, in <module>
#     main()
#   File "/home/yoxara/smodels/smodels/tools/runSModelS.py", line 73, in main
#     run(args.filename, args.parameterFile, args.outputDir,
#   File "/home/yoxara/smodels/smodels/tools/runSModelS.py", line 99, in run
#     database = modelTester.loadDatabase(parser, db)
#   File "/home/yoxara/smodels/smodels/matching/modelTester.py", line 472, in loadDatabase
#     database = Database(databasePath, force_load=force_load)
#   File "/home/yoxara/smodels/smodels/experiment/databaseObj.py", line 109, in __init__
#     self.subs.append(SubDatabase(ss, force_load,
#   File "/home/yoxara/smodels/smodels/experiment/databaseObj.py", line 419, in __init__
#     self.loadDatabase()
#   File "/home/yoxara/smodels/smodels/experiment/databaseObj.py", line 468, in loadDatabase
#     self.loadTextDatabase()
#   File "/home/yoxara/smodels/smodels/experiment/databaseObj.py", line 482, in loadTextDatabase
#     self.expResultList = self._loadExpResults()
#   File "/home/yoxara/smodels/smodels/experiment/databaseObj.py", line 1008, in _loadExpResults
#     expres = self.createExpResult(root)
#   File "/home/yoxara/smodels/smodels/experiment/databaseObj.py", line 1045, in createExpResult
#     expres = ExpResult(root,
#   File "/home/yoxara/smodels/smodels/experiment/expResultObj.py", line 63, in __init__
#     dataset = datasetObj.DataSet(root, self.globalInfo,
#   File "/home/yoxara/smodels/smodels/experiment/datasetObj.py", line 59, in __init__
#     txname = txnameObj.TxName(txtfile, self.globalInfo,
#   File "/home/yoxara/smodels/smodels/experiment/txnameObj.py", line 85, in __init__
#     value = line.split(':', 1)[1].strip()
# IndexError: list index out of range

# %%
#Convert Experimental Results list to a dictionary
data = []
removeFromDict = ['topologies outside the grid',"missing topologies",
                  "missing topologies with displaced decays", 'missing topologies with prompt decays',
                 "Asymmetric Branches","Outside Grid","Missed Topologies","Long Cascades"]
for f in glob.glob(resultsFolder+'/*.py'):
    with open(f,'r') as ff:
        dataF = ff.read()
    dataF = dataF.replace('inf','-1')
    with open(f.replace('.py','_fix.py'),'w') as ff:
        ff.write(dataF)
    f = f.replace('.py','_fix.py')
    smodelsDict = imp.load_source(f.replace('.py',''),f).smodelsOutput
    for rmKey in removeFromDict:
        if rmKey in smodelsDict:
            smodelsDict.pop(rmKey)
    if 'ExptRes' in smodelsDict:
        for res in smodelsDict['ExptRes']:
            if 'TxNames weights (fb)' in res:
                res.pop('TxNames weights (fb)')  
        expList = sorted(smodelsDict['ExptRes'], key=lambda pt: pt['r'],reverse=True)
        expDict = dict([['result%i'%i,val] for i,val in enumerate(expList)])
        smodelsDict['ExptRes'] = expDict
    slhaFile = smodelsDict['OutputStatus']['input file']
    dataDict = {'filename' : os.path.basename(slhaFile)}
    dataDict.update(smodelsDict)
    data.append(dataDict)

# %%
print(len(data))
# Out:
# 2

# %%
#Convert data to flat DataFrame:
pd.set_option('display.float_format', '{:e}'.format)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 5)
smodelsDF = json_normalize(data)
smodelsDF
# Out:
#                                         filename  \
# 0  run_01_mzp_1000.1_mx_450.1_nevents_70000.slha
# 1  run_01_mzp_1000.1_mx_450.1_nevents_70000.slha
#
#                                    SMS Decomposition  \
# 0  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# 1  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
#
#    Total xsec for missing topologies (fb)  \
# 0                            1.375300e+03
# 1                            1.375300e+03
#
#    Total xsec for missing topologies with displaced decays (fb)  \
# 0                                       0.000000e+00
# 1                                       0.000000e+00
#
#    Total xsec for missing topologies with prompt decays (fb)  \
# 0                                       1.375300e+03
# 1                                       1.375300e+03
#
#    Total xsec for topologies outside the grid (fb)  OutputStatus.sigmacut  \
# 0                                     0.000000e+00           0.000000e+00
# 1                                     0.000000e+00           0.000000e+00
#
#    OutputStatus.minmassgap  OutputStatus.maxcond  OutputStatus.ncpus  \
# 0                        5          2.000000e-01                   1
# 1                        5          2.000000e-01                   1
#
#                                   OutputStatus.model  \
# 0  TRV1_slha/run_01_mzp_1000.1_mx_450.1_nevents_7...
# 1  TRV1_slha/run_01_mzp_1000.1_mx_450.1_nevents_7...
#
#    OutputStatus.promptwidth  OutputStatus.stablewidth  \
# 0              5.000000e+00              1.000000e-25
# 1              5.000000e+00              1.000000e-25
#
#   OutputStatus.eraseprompt  OutputStatus.checkinput  OutputStatus.doinvisible  \
# 0         eCharge,colordim                     True                      True
# 1         eCharge,colordim                     True                      True
#
#    OutputStatus.docompress  OutputStatus.computestatistics  \
# 0                     True                            True
# 1                     True                            True
#
#    OutputStatus.testcoverage  OutputStatus.combinesrs  \
# 0                       True                    False
# 1                       True                    False
#
#    OutputStatus.reportallsrs  OutputStatus.experimentalfeatures  \
# 0                      False                              False
# 1                      False                              False
#
#    OutputStatus.file status  OutputStatus.decomposition status  \
# 0                         1                                  0
# 1                         1                                  0
#
#   OutputStatus.warnings                            OutputStatus.input file  \
# 0         Input file ok  TRV1_slha/run_01_mzp_1000.1_mx_450.1_nevents_7...
# 1         Input file ok  TRV1_slha/run_01_mzp_1000.1_mx_450.1_nevents_7...
#
#   OutputStatus.database version OutputStatus.smodels version
# 0                    3.0.0-beta                   3.0.0-beta
# 1                    3.0.0-beta                   3.0.0-beta

# %%
#Get SLHA data:
slhaData = []
for f in smodelsDF['filename']:
    slhaFile = os.path.join(slhaFolder,f)
    slha = pyslha.readSLHAFile(slhaFile)
    massDict = dict([[str(key),abs(val)] for key,val in slha.blocks['MASS'].items() if key >=52])
    extparDict = dict([[str(key),val] for key,val in slha.blocks['DMINPUTS'].items()])
    #extparDict.update(dict([[str(key),val] for key,val in slha.blocks['BLINPUTS'].items()]))
    widthDict = dict([[str(key),val.totalwidth] for key,val in slha.decays.items() if key >= 55])
    BRsDict = {}
    for pdg,val in slha.decays.items():
#         if not abs(pdg) in [1000024,1000023]:
#             continue
        initialState = model.getParticlesWith(pdg=pdg)[0].label            
        BRsDict[initialState] = {}
        for dec in val.decays:
            if dec.br < 0.01: continue            
            finalState = ','.join([model.getParticlesWith(pdg=pid)[0].label for pid in sorted(dec.ids)])
            BRsDict[initialState][finalState] = dec.br
    xsec8TeV = dict([ [str(proc.pidsfinal).replace('[','').replace(']','').replace(',','_').replace(' ',''),
                   max([x.value for x in proc.get_xsecs(sqrts=8000)])*1000] 
                 for proc in slha.xsections.values()  if proc.get_xsecs(sqrts=8000)])
    xsec13TeV = dict([ [str(proc.pidsfinal).replace('[','').replace(']','').replace(',','_').replace(' ',''),
                   max([x.value for x in proc.get_xsecs(sqrts=13000)])*1000] 
                 for proc in slha.xsections.values()  if proc.get_xsecs(sqrts=13000)])    
    slhaDict = {'filename' : f, 'mass' : massDict, 'width' : widthDict, 'extpar' : extparDict, 
                'xsec8TeV(fb)' : xsec8TeV, 'xsec13TeV(fb)' : xsec13TeV, 'BRs' : BRsDict}
    slhaData.append(slhaDict)

# %%
#Convert to DataFrame
slhaDF = json_normalize(slhaData)
#Add total cross-sections:
xsecs13 = [x for x in list(slhaDF) if 'xsec13TeV' in x]
xsecs8 = [x for x in list(slhaDF) if 'xsec8TeV' in x]
slhaDF['totalxsec13TeV(fb)'] = slhaDF[xsecs13].sum(axis=1)
slhaDF['totalxsec8TeV(fb)'] = slhaDF[xsecs8].sum(axis=1)

# %%
#Merge with SModelS DataFrame
dataDF = slhaDF.merge(smodelsDF,how='inner')

# %%
print('Final number of data points:',dataDF.shape[0])
#print(dataDF2.columns.values.tolist()) #Print all columns names
# Out:
# Final number of data points: 4

# %%
#Save DataFrame to pickle file:
dataDF.to_csv('TRV1.csv')
print(len(dataDF))
dataDF
# Out:
# 4
#                                         filename      mass.52      mass.55  \
# 0  run_01_mzp_1000.1_mx_450.1_nevents_70000.slha 4.501100e+02 1.000100e+03
# 1  run_01_mzp_1000.1_mx_450.1_nevents_70000.slha 4.501100e+02 1.000100e+03
# 2  run_01_mzp_1000.1_mx_450.1_nevents_70000.slha 4.501100e+02 1.000100e+03
# 3  run_01_mzp_1000.1_mx_450.1_nevents_70000.slha 4.501100e+02 1.000100e+03
#
#    mass.5000001  mass.9000002  mass.9000003  mass.9000004     width.55  \
# 0  0.000000e+00  9.118760e+01  7.982436e+01  7.982436e+01 3.118145e+01
# 1  0.000000e+00  9.118760e+01  7.982436e+01  7.982436e+01 3.118145e+01
# 2  0.000000e+00  9.118760e+01  7.982436e+01  7.982436e+01 3.118145e+01
# 3  0.000000e+00  9.118760e+01  7.982436e+01  7.982436e+01 3.118145e+01
#
#    width.5000001  width.9000002  width.9000003  width.9000004     extpar.1  \
# 0   0.000000e+00   2.495200e+00   2.085000e+00   2.085000e+00 0.000000e+00
# 1   0.000000e+00   2.495200e+00   2.085000e+00   2.085000e+00 0.000000e+00
# 2   0.000000e+00   2.495200e+00   2.085000e+00   2.085000e+00 0.000000e+00
# 3   0.000000e+00   2.495200e+00   2.085000e+00   2.085000e+00 0.000000e+00
#
#       extpar.2     extpar.3     extpar.4     extpar.5     extpar.6  \
# 0 0.000000e+00 1.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 1 0.000000e+00 1.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 2 0.000000e+00 1.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 3 0.000000e+00 1.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
#
#       extpar.7     extpar.8     extpar.9    extpar.10    extpar.11  \
# 0 0.000000e+00 0.000000e+00 0.000000e+00 2.500000e-01 2.500000e-01
# 1 0.000000e+00 0.000000e+00 0.000000e+00 2.500000e-01 2.500000e-01
# 2 0.000000e+00 0.000000e+00 0.000000e+00 2.500000e-01 2.500000e-01
# 3 0.000000e+00 0.000000e+00 0.000000e+00 2.500000e-01 2.500000e-01
#
#      extpar.12    extpar.13    extpar.14    extpar.15    extpar.16  \
# 0 2.500000e-01 2.500000e-01 2.500000e-01 2.500000e-01 0.000000e+00
# 1 2.500000e-01 2.500000e-01 2.500000e-01 2.500000e-01 0.000000e+00
# 2 2.500000e-01 2.500000e-01 2.500000e-01 2.500000e-01 0.000000e+00
# 3 2.500000e-01 2.500000e-01 2.500000e-01 2.500000e-01 0.000000e+00
#
#    xsec13TeV(fb).55   BRs.y1.b,b   BRs.y1.c,c   BRs.y1.q,q  BRs.y1.t-,t+  \
# 0      1.375300e+03 1.595208e-01 1.595208e-01 1.595208e-01  1.320655e-01
# 1      1.375300e+03 1.595208e-01 1.595208e-01 1.595208e-01  1.320655e-01
# 2      1.375300e+03 1.595208e-01 1.595208e-01 1.595208e-01  1.320655e-01
# 3      1.375300e+03 1.595208e-01 1.595208e-01 1.595208e-01  1.320655e-01
#
#    BRs.y1.xd~,xd  totalxsec13TeV(fb)  totalxsec8TeV(fb)  \
# 0   7.033049e-02        1.375300e+03       0.000000e+00
# 1   7.033049e-02        1.375300e+03       0.000000e+00
# 2   7.033049e-02        1.375300e+03       0.000000e+00
# 3   7.033049e-02        1.375300e+03       0.000000e+00
#
#                                    SMS Decomposition  \
# 0  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# 1  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# 2  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# 3  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
#
#    Total xsec for missing topologies (fb)  \
# 0                            1.375300e+03
# 1                            1.375300e+03
# 2                            1.375300e+03
# 3                            1.375300e+03
#
#    Total xsec for missing topologies with displaced decays (fb)  \
# 0                                       0.000000e+00
# 1                                       0.000000e+00
# 2                                       0.000000e+00
# 3                                       0.000000e+00
#
#    Total xsec for missing topologies with prompt decays (fb)  \
# 0                                       1.375300e+03
# 1                                       1.375300e+03
# 2                                       1.375300e+03
# 3                                       1.375300e+03
#
#    Total xsec for topologies outside the grid (fb)  OutputStatus.sigmacut  \
# 0                                     0.000000e+00           0.000000e+00
# 1                                     0.000000e+00           0.000000e+00
# 2                                     0.000000e+00           0.000000e+00
# 3                                     0.000000e+00           0.000000e+00
#
#    OutputStatus.minmassgap  OutputStatus.maxcond  OutputStatus.ncpus  \
# 0                        5          2.000000e-01                   1
# 1                        5          2.000000e-01                   1
# 2                        5          2.000000e-01                   1
# 3                        5          2.000000e-01                   1
#
#                                   OutputStatus.model  \
# 0  TRV1_slha/run_01_mzp_1000.1_mx_450.1_nevents_7...
# 1  TRV1_slha/run_01_mzp_1000.1_mx_450.1_nevents_7...
# 2  TRV1_slha/run_01_mzp_1000.1_mx_450.1_nevents_7...
# 3  TRV1_slha/run_01_mzp_1000.1_mx_450.1_nevents_7...
#
#    OutputStatus.promptwidth  OutputStatus.stablewidth  \
# 0              5.000000e+00              1.000000e-25
# 1              5.000000e+00              1.000000e-25
# 2              5.000000e+00              1.000000e-25
# 3              5.000000e+00              1.000000e-25
#
#   OutputStatus.eraseprompt  OutputStatus.checkinput  OutputStatus.doinvisible  \
# 0         eCharge,colordim                     True                      True
# 1         eCharge,colordim                     True                      True
# 2         eCharge,colordim                     True                      True
# 3         eCharge,colordim                     True                      True
#
#    OutputStatus.docompress  OutputStatus.computestatistics  \
# 0                     True                            True
# 1                     True                            True
# 2                     True                            True
# 3                     True                            True
#
#    OutputStatus.testcoverage  OutputStatus.combinesrs  \
# 0                       True                    False
# 1                       True                    False
# 2                       True                    False
# 3                       True                    False
#
#    OutputStatus.reportallsrs  OutputStatus.experimentalfeatures  \
# 0                      False                              False
# 1                      False                              False
# 2                      False                              False
# 3                      False                              False
#
#    OutputStatus.file status  OutputStatus.decomposition status  \
# 0                         1                                  0
# 1                         1                                  0
# 2                         1                                  0
# 3                         1                                  0
#
#   OutputStatus.warnings                            OutputStatus.input file  \
# 0         Input file ok  TRV1_slha/run_01_mzp_1000.1_mx_450.1_nevents_7...
# 1         Input file ok  TRV1_slha/run_01_mzp_1000.1_mx_450.1_nevents_7...
# 2         Input file ok  TRV1_slha/run_01_mzp_1000.1_mx_450.1_nevents_7...
# 3         Input file ok  TRV1_slha/run_01_mzp_1000.1_mx_450.1_nevents_7...
#
#   OutputStatus.database version OutputStatus.smodels version
# 0                    3.0.0-beta                   3.0.0-beta
# 1                    3.0.0-beta                   3.0.0-beta
# 2                    3.0.0-beta                   3.0.0-beta
# 3                    3.0.0-beta                   3.0.0-beta

# %%
#dataDF['xsec13TeV(fb).55'] *(3 *dataDF['BRs.y1.'] )

# %%
dataDF['ExptRes.result0.theory prediction (fb)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3801         try:
# -> 3802             return self._engine.get_loc(casted_key)
#    3803         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ExptRes.result0.theory prediction (fb)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_11013/671257298.py in <module>
# ----> 1 dataDF['ExptRes.result0.theory prediction (fb)']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4088             if self.columns.nlevels > 1:
#    4089                 return self._getitem_multilevel(key)
# -> 4090             indexer = self.columns.get_loc(key)
#    4091             if is_integer(indexer):
#    4092                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3807             ):
#    3808                 raise InvalidIndexError(key)
# -> 3809             raise KeyError(key) from err
#    3810         except TypeError:
#    3811             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ExptRes.result0.theory prediction (fb)'

# %%
#(dataDF['xsec13TeV(fb).55'] *(3 *dataDF['BRs.y1.q,q'] + dataDF['BRs.y1.c,c'] + dataDF['BRs.y1.b,b'] ))/dataDF['ExptRes.result0.theory prediction (fb)']

# %%
mask = dataDF['ExptRes.result0.r'].isna()
rows_with_nan = dataDF[mask]
rows_with_nan
#print(rows_with_nan)

# %%
mask = dataDF['ExptRes.result0.r'].isna()
rows_with_nan = dataDF[mask]
rows_with_nan.to_csv('rows_with_nan_.csv', index=False)
rows_with_nan
