# %%
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
import sys, re, os
import numpy as np
import pandas as pd
import glob,imp
from pandas import json_normalize
import pyslha
sys.path.append('../../smodels')
from smodels.particlesLoader import getParticlesFromSLHA
pd.options.mode.chained_assignment = None #Disable copy warnings
from smodels.experiment.databaseObj import Database
from smodels.base.model import Model
from smodels.decomposition import decomposer
from smodels.matching.theoryPrediction import theoryPredictionsFor
from smodels.base.physicsUnits import fb, GeV
#from smodels.share.models.ppZpjj import BSMList
from smodels.share.models.SMparticles import SMList
from smodels.base.smodelsLogging import setLogLevel
from smodels.base import runtime
from smodels.experiment.expSMS import ExpSMS
from smodels.experiment.defaultFinalStates import finalStates
setLogLevel("info")
#runtime.modelFile = 'smodels.share.models.ppZpjj'
# !runSModelS.py -V
# Out:
# 3.0.0-beta

# %%
BSMlist = getParticlesFromSLHA('TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha')
model = Model(BSMparticles=BSMlist, SMparticles=SMList)
print(BSMlist)
# Out:
# [gha, gha~, ghz, ghz~, ghwp, ghwp~, ghwm, ghwm~, ghg, ghg~, xr, xc, xc~, xd, xd~, y1]

# %%
slhaFolder = 'TRV1jj_slha_broad'
resultsFolder = 'TRV1jj_results_broad'
File = 'parameters.ini'
# !chmod -R +rwx {slhaFolder}

# %%
# !runSModelS.py -p {File} -f {slhaFolder} -o {resultsFolder}
# Out:
# INFO in databaseObj.loadTextDatabase() in 479: Parsing text database at /home/yoxara/smodels-database/
# INFO in databaseObj.createBinaryFile() in 630: /home/yoxara/smodels-database/db3.pcl created.
# INFO in modelTester.loadDatabaseResults() in 497: Including non-validated results
# INFO in modelTester.testPoints() in 357: Running SModelS for 645 files with a single process. Messages will be redirected to smodels.log

# %%
#Convert Experimental Results list to a dictionary
data = []
removeFromDict = ['topologies outside the grid',"missing topologies",
                  "missing topologies with displaced decays", 'missing topologies with prompt decays',
                 "Asymmetric Branches","Outside Grid","Missed Topologies","Long Cascades"]
for f in glob.glob(resultsFolder+'/*.py'):
    with open(f,'r') as ff:
        dataF = ff.read()
    dataF = dataF.replace('inf','-1')
    with open(f.replace('.py','_fix.py'),'w') as ff:
        ff.write(dataF)
    f = f.replace('.py','_fix.py')
    smodelsDict = imp.load_source(f.replace('.py',''),f).smodelsOutput
    for rmKey in removeFromDict:
        if rmKey in smodelsDict:
            smodelsDict.pop(rmKey)
    if 'ExptRes' in smodelsDict:
        for res in smodelsDict['ExptRes']:
            if 'TxNames weights (fb)' in res:
                res.pop('TxNames weights (fb)')  
        expList = sorted(smodelsDict['ExptRes'], key=lambda pt: pt['r'],reverse=True)
        expDict = dict([['result%i'%i,val] for i,val in enumerate(expList)])
        smodelsDict['ExptRes'] = expDict
    slhaFile = smodelsDict['OutputStatus']['input file']
    dataDict = {'filename' : os.path.basename(slhaFile)}
    dataDict.update(smodelsDict)
    data.append(dataDict)

# %%
print(len(data))
# Out:
# 645

# %%
#Convert data to flat DataFrame:
pd.set_option('display.float_format', '{:e}'.format)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 5)
smodelsDF = json_normalize(data)
smodelsDF
# Out:
#                            filename  \
# 0    run_449_mzp_4700_gvq_0.63.slha
# 1    run_333_mzp_4000_gvq_0.19.slha
# ..                              ...
# 643  run_454_mzp_4800_gvq_0.22.slha
# 644  run_346_mzp_4100_gvq_0.13.slha
#
#                                      SMS Decomposition  \
# 0    [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# 1    [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# ..                                                 ...
# 643  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# 644  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
#
#      Total xsec for missing topologies (fb)  \
# 0                              2.715551e+00
# 1                              2.816803e+00
# ..                                      ...
# 643                            6.069257e-01
# 644                            1.296949e+00
#
#      Total xsec for missing topologies with displaced decays (fb)  \
# 0                                         0.000000e+00
# 1                                         0.000000e+00
# ..                                                 ...
# 643                                       0.000000e+00
# 644                                       0.000000e+00
#
#      Total xsec for missing topologies with prompt decays (fb)  \
# 0                                         1.013700e+01
# 1                                         4.228500e+00
# ..                                                 ...
# 643                                       9.964600e-01
# 644                                       1.623500e+00
#
#      Total xsec for topologies outside the grid (fb)  OutputStatus.sigmacut  \
# 0                                       0.000000e+00           0.000000e+00
# 1                                       0.000000e+00           0.000000e+00
# ..                                               ...                    ...
# 643                                     0.000000e+00           0.000000e+00
# 644                                     0.000000e+00           0.000000e+00
#
#      OutputStatus.minmassgap  OutputStatus.maxcond  OutputStatus.ncpus  \
# 0                          5          2.000000e-01                   1
# 1                          5          2.000000e-01                   1
# ..                       ...                   ...                 ...
# 643                        5          2.000000e-01                   1
# 644                        5          2.000000e-01                   1
#
#                                   OutputStatus.model  \
# 0    TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
# 1    TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
# ..                                               ...
# 643  TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
# 644  TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
#
#      OutputStatus.promptwidth  OutputStatus.stablewidth  \
# 0                5.000000e+00              1.000000e-25
# 1                5.000000e+00              1.000000e-25
# ..                        ...                       ...
# 643              5.000000e+00              1.000000e-25
# 644              5.000000e+00              1.000000e-25
#
#     OutputStatus.eraseprompt  OutputStatus.checkinput  \
# 0           eCharge,colordim                     True
# 1           eCharge,colordim                     True
# ..                       ...                      ...
# 643         eCharge,colordim                     True
# 644         eCharge,colordim                     True
#
#      OutputStatus.doinvisible  OutputStatus.docompress  \
# 0                        True                     True
# 1                        True                     True
# ..                        ...                      ...
# 643                      True                     True
# 644                      True                     True
#
#      OutputStatus.computestatistics  OutputStatus.testcoverage  \
# 0                              True                       True
# 1                              True                       True
# ..                              ...                        ...
# 643                            True                       True
# 644                            True                       True
#
#      OutputStatus.combinesrs  OutputStatus.reportallsrs  \
# 0                      False                      False
# 1                      False                      False
# ..                       ...                        ...
# 643                    False                      False
# 644                    False                      False
#
#      OutputStatus.experimentalfeatures  OutputStatus.file status  \
# 0                                False                         1
# 1                                False                         1
# ..                                 ...                       ...
# 643                              False                         1
# 644                              False                         1
#
#      OutputStatus.decomposition status OutputStatus.warnings  \
# 0                                    1         Input file ok
# 1                                    1         Input file ok
# ..                                 ...                   ...
# 643                                  1         Input file ok
# 644                                  1         Input file ok
#
#                               OutputStatus.input file  \
# 0    TRV1jj_slha_broad/run_449_mzp_4700_gvq_0.63.slha
# 1    TRV1jj_slha_broad/run_333_mzp_4000_gvq_0.19.slha
# ..                                                ...
# 643  TRV1jj_slha_broad/run_454_mzp_4800_gvq_0.22.slha
# 644  TRV1jj_slha_broad/run_346_mzp_4100_gvq_0.13.slha
#
#     OutputStatus.database version OutputStatus.smodels version  \
# 0                      3.0.0-beta                   3.0.0-beta
# 1                      3.0.0-beta                   3.0.0-beta
# ..                            ...                          ...
# 643                    3.0.0-beta                   3.0.0-beta
# 644                    3.0.0-beta                   3.0.0-beta
#
#      ExptRes.result0.maxcond  ExptRes.result0.theory prediction (fb)  \
# 0               0.000000e+00                            7.421450e+00
# 1               0.000000e+00                            1.411697e+00
# ..                       ...                                     ...
# 643             0.000000e+00                            3.895343e-01
# 644             0.000000e+00                            3.265514e-01
#
#      ExptRes.result0.upper limit (fb)  \
# 0                        1.458480e+01
# 1                        1.838170e+01
# ..                                ...
# 643                      5.945770e+00
# 644                      1.338840e+01
#
#      ExptRes.result0.expected upper limit (fb) ExptRes.result0.TxNames  \
# 0                                          NaN                [TRV1jj]
# 1                                          NaN                [TRV1jj]
# ..                                         ...                     ...
# 643                                        NaN                [TRV1jj]
# 644                                        NaN                [TRV1jj]
#
#     ExptRes.result0.Mass (GeV) ExptRes.result0.AnalysisID  \
# 0               [(y1, 4700.0)]             CMS-EXO-19-012
# 1               [(y1, 4000.0)]             CMS-EXO-19-012
# ..                         ...                        ...
# 643             [(y1, 4800.0)]             CMS-EXO-19-012
# 644             [(y1, 4100.0)]             CMS-EXO-19-012
#
#      ExptRes.result0.DataSetID  ExptRes.result0.AnalysisSqrts (TeV)  \
# 0                          NaN                         1.300000e+01
# 1                          NaN                         1.300000e+01
# ..                         ...                                  ...
# 643                        NaN                         1.300000e+01
# 644                        NaN                         1.300000e+01
#
#      ExptRes.result0.lumi (fb-1) ExptRes.result0.dataType  ExptRes.result0.r  \
# 0                   1.370000e+02               upperLimit       5.088482e-01
# 1                   1.370000e+02               upperLimit       7.679907e-02
# ..                           ...                      ...                ...
# 643                 1.370000e+02               upperLimit       6.551453e-02
# 644                 1.370000e+02               upperLimit       2.439062e-02
#
#      ExptRes.result0.r_expected ExptRes.result0.Width (GeV)
# 0                           NaN              [(y1, 1026.4)]
# 1                           NaN              [(y1, 177.02)]
# ..                          ...                         ...
# 643                         NaN              [(y1, 239.83)]
# 644                         NaN              [(y1, 143.36)]
#
# [645 rows x 42 columns]

# %%
#Get SLHA data:
slhaData = []
for f in smodelsDF['filename']:
    slhaFile = os.path.join(slhaFolder,f)
    slha = pyslha.readSLHAFile(slhaFile)
    massDict = dict([[str(key),abs(val)] for key,val in slha.blocks['MASS'].items() if key >=55])
    extparDict = dict([[str(key),val] for key,val in slha.blocks['DMINPUTS'].items()])
    #extparDict.update(dict([[str(key),val] for key,val in slha.blocks['BLINPUTS'].items()]))
    widthDict = dict([[str(key),val.totalwidth] for key,val in slha.decays.items() if key >= 55])
    BRsDict = {}
    for pdg,val in slha.decays.items():
#         if not abs(pdg) in [1000024,1000023]:
#             continue
        initialState = model.getParticlesWith(pdg=pdg)[0].label            
        BRsDict[initialState] = {}
        for dec in val.decays:
            if dec.br < 0.01: continue            
            finalState = ','.join([model.getParticlesWith(pdg=pid)[0].label for pid in sorted(dec.ids)])
            BRsDict[initialState][finalState] = dec.br
    xsec8TeV = dict([ [str(proc.pidsfinal).replace('[','').replace(']','').replace(',','_').replace(' ',''),
                   max([x.value for x in proc.get_xsecs(sqrts=8000)])*1000] 
                 for proc in slha.xsections.values()  if proc.get_xsecs(sqrts=8000)])
    xsec13TeV = dict([ [str(proc.pidsfinal).replace('[','').replace(']','').replace(',','_').replace(' ',''),
                   max([x.value for x in proc.get_xsecs(sqrts=13000)])*1000] 
                 for proc in slha.xsections.values()  if proc.get_xsecs(sqrts=13000)])    
    slhaDict = {'filename' : f, 'mass' : massDict, 'width' : widthDict, 'extpar' : extparDict, 
                'xsec8TeV(fb)' : xsec8TeV, 'xsec13TeV(fb)' : xsec13TeV, 'BRs' : BRsDict}
    slhaData.append(slhaDict)

# %%
#Convert to DataFrame
slhaDF = json_normalize(slhaData)
#Add total cross-sections:
xsecs13 = [x for x in list(slhaDF) if 'xsec13TeV' in x]
xsecs8 = [x for x in list(slhaDF) if 'xsec8TeV' in x]
slhaDF['totalxsec13TeV(fb)'] = slhaDF[xsecs13].sum(axis=1)
slhaDF['totalxsec8TeV(fb)'] = slhaDF[xsecs8].sum(axis=1)

# %%
#Merge with SModelS DataFrame
dataDF = slhaDF.merge(smodelsDF,how='inner')

# %%
print('Final number of data points:',dataDF.shape[0])
#print(dataDF2.columns.values.tolist()) #Print all columns names
# Out:
# Final number of data points: 645

# %%
#Save DataFrame to pickle file:
dataDF.to_csv('TRV1jj_broad.csv')
print(len(dataDF))
dataDF
# Out:
# 645
#                            filename      mass.55  mass.5000001  mass.9000002  \
# 0    run_449_mzp_4700_gvq_0.63.slha 4.700000e+03  0.000000e+00  9.118760e+01
# 1    run_333_mzp_4000_gvq_0.19.slha 4.000000e+03  0.000000e+00  9.118760e+01
# ..                              ...          ...           ...           ...
# 643  run_454_mzp_4800_gvq_0.22.slha 4.800000e+03  0.000000e+00  9.118760e+01
# 644  run_346_mzp_4100_gvq_0.13.slha 4.100000e+03  0.000000e+00  9.118760e+01
#
#      mass.9000003  mass.9000004     width.55  width.5000001  width.9000002  \
# 0    7.982436e+01  7.982436e+01 1.026409e+03   0.000000e+00   2.495200e+00
# 1    7.982436e+01  7.982436e+01 1.770224e+02   0.000000e+00   2.495200e+00
# ..            ...           ...          ...            ...            ...
# 643  7.982436e+01  7.982436e+01 2.398271e+02   0.000000e+00   2.495200e+00
# 644  7.982436e+01  7.982436e+01 1.433578e+02   0.000000e+00   2.495200e+00
#
#      width.9000003  width.9000004     extpar.1     extpar.2     extpar.3  \
# 0     2.085000e+00   2.085000e+00 0.000000e+00 1.000000e+00 0.000000e+00
# 1     2.085000e+00   2.085000e+00 0.000000e+00 1.000000e+00 0.000000e+00
# ..             ...            ...          ...          ...          ...
# 643   2.085000e+00   2.085000e+00 0.000000e+00 1.000000e+00 0.000000e+00
# 644   2.085000e+00   2.085000e+00 0.000000e+00 1.000000e+00 0.000000e+00
#
#         extpar.4     extpar.5     extpar.6     extpar.7     extpar.8  \
# 0   6.339000e-01 6.339000e-01 6.339000e-01 6.339000e-01 6.339000e-01
# 1   1.927000e-01 1.927000e-01 1.927000e-01 1.927000e-01 1.927000e-01
# ..           ...          ...          ...          ...          ...
# 643 2.215600e-01 2.215600e-01 2.215600e-01 2.215600e-01 2.215600e-01
# 644 1.329500e-01 1.329500e-01 1.329500e-01 1.329500e-01 1.329500e-01
#
#         extpar.9    extpar.10    extpar.11    extpar.12    extpar.13  \
# 0   6.339000e-01 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 1   1.927000e-01 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# ..           ...          ...          ...          ...          ...
# 643 2.215600e-01 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 644 1.329500e-01 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
#
#        extpar.14    extpar.15    extpar.16  xsec13TeV(fb).55   BRs.y1.b,b  \
# 0   0.000000e+00 0.000000e+00 0.000000e+00      1.013700e+01 1.464230e-01
# 1   0.000000e+00 0.000000e+00 0.000000e+00      4.228500e+00 6.677060e-02
# ..           ...          ...          ...               ...          ...
# 643 0.000000e+00 0.000000e+00 0.000000e+00      9.964600e-01 7.818363e-02
# 644 0.000000e+00 0.000000e+00 0.000000e+00      1.623500e+00 4.022808e-02
#
#       BRs.y1.c,c   BRs.y1.q,q  BRs.y1.t-,t+  BRs.y1.xd~,xd  \
# 0   1.464230e-01 1.464230e-01  1.464214e-01   1.214637e-01
# 1   6.677060e-02 6.677060e-02  6.676923e-02   5.993778e-01
# ..           ...          ...           ...            ...
# 643 7.818363e-02 7.818363e-02  7.818286e-02   5.308990e-01
# 644 4.022808e-02 4.022808e-02  4.022733e-02   7.586323e-01
#
#      totalxsec13TeV(fb)  totalxsec8TeV(fb)  \
# 0          1.013700e+01       0.000000e+00
# 1          4.228500e+00       0.000000e+00
# ..                  ...                ...
# 643        9.964600e-01       0.000000e+00
# 644        1.623500e+00       0.000000e+00
#
#                                      SMS Decomposition  \
# 0    [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# 1    [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# ..                                                 ...
# 643  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# 644  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
#
#      Total xsec for missing topologies (fb)  \
# 0                              2.715551e+00
# 1                              2.816803e+00
# ..                                      ...
# 643                            6.069257e-01
# 644                            1.296949e+00
#
#      Total xsec for missing topologies with displaced decays (fb)  \
# 0                                         0.000000e+00
# 1                                         0.000000e+00
# ..                                                 ...
# 643                                       0.000000e+00
# 644                                       0.000000e+00
#
#      Total xsec for missing topologies with prompt decays (fb)  \
# 0                                         1.013700e+01
# 1                                         4.228500e+00
# ..                                                 ...
# 643                                       9.964600e-01
# 644                                       1.623500e+00
#
#      Total xsec for topologies outside the grid (fb)  OutputStatus.sigmacut  \
# 0                                       0.000000e+00           0.000000e+00
# 1                                       0.000000e+00           0.000000e+00
# ..                                               ...                    ...
# 643                                     0.000000e+00           0.000000e+00
# 644                                     0.000000e+00           0.000000e+00
#
#      OutputStatus.minmassgap  OutputStatus.maxcond  OutputStatus.ncpus  \
# 0                          5          2.000000e-01                   1
# 1                          5          2.000000e-01                   1
# ..                       ...                   ...                 ...
# 643                        5          2.000000e-01                   1
# 644                        5          2.000000e-01                   1
#
#                                   OutputStatus.model  \
# 0    TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
# 1    TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
# ..                                               ...
# 643  TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
# 644  TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
#
#      OutputStatus.promptwidth  OutputStatus.stablewidth  \
# 0                5.000000e+00              1.000000e-25
# 1                5.000000e+00              1.000000e-25
# ..                        ...                       ...
# 643              5.000000e+00              1.000000e-25
# 644              5.000000e+00              1.000000e-25
#
#     OutputStatus.eraseprompt  OutputStatus.checkinput  \
# 0           eCharge,colordim                     True
# 1           eCharge,colordim                     True
# ..                       ...                      ...
# 643         eCharge,colordim                     True
# 644         eCharge,colordim                     True
#
#      OutputStatus.doinvisible  OutputStatus.docompress  \
# 0                        True                     True
# 1                        True                     True
# ..                        ...                      ...
# 643                      True                     True
# 644                      True                     True
#
#      OutputStatus.computestatistics  OutputStatus.testcoverage  \
# 0                              True                       True
# 1                              True                       True
# ..                              ...                        ...
# 643                            True                       True
# 644                            True                       True
#
#      OutputStatus.combinesrs  OutputStatus.reportallsrs  \
# 0                      False                      False
# 1                      False                      False
# ..                       ...                        ...
# 643                    False                      False
# 644                    False                      False
#
#      OutputStatus.experimentalfeatures  OutputStatus.file status  \
# 0                                False                         1
# 1                                False                         1
# ..                                 ...                       ...
# 643                              False                         1
# 644                              False                         1
#
#      OutputStatus.decomposition status OutputStatus.warnings  \
# 0                                    1         Input file ok
# 1                                    1         Input file ok
# ..                                 ...                   ...
# 643                                  1         Input file ok
# 644                                  1         Input file ok
#
#                               OutputStatus.input file  \
# 0    TRV1jj_slha_broad/run_449_mzp_4700_gvq_0.63.slha
# 1    TRV1jj_slha_broad/run_333_mzp_4000_gvq_0.19.slha
# ..                                                ...
# 643  TRV1jj_slha_broad/run_454_mzp_4800_gvq_0.22.slha
# 644  TRV1jj_slha_broad/run_346_mzp_4100_gvq_0.13.slha
#
#     OutputStatus.database version OutputStatus.smodels version  \
# 0                      3.0.0-beta                   3.0.0-beta
# 1                      3.0.0-beta                   3.0.0-beta
# ..                            ...                          ...
# 643                    3.0.0-beta                   3.0.0-beta
# 644                    3.0.0-beta                   3.0.0-beta
#
#      ExptRes.result0.maxcond  ExptRes.result0.theory prediction (fb)  \
# 0               0.000000e+00                            7.421450e+00
# 1               0.000000e+00                            1.411697e+00
# ..                       ...                                     ...
# 643             0.000000e+00                            3.895343e-01
# 644             0.000000e+00                            3.265514e-01
#
#      ExptRes.result0.upper limit (fb)  \
# 0                        1.458480e+01
# 1                        1.838170e+01
# ..                                ...
# 643                      5.945770e+00
# 644                      1.338840e+01
#
#      ExptRes.result0.expected upper limit (fb) ExptRes.result0.TxNames  \
# 0                                          NaN                [TRV1jj]
# 1                                          NaN                [TRV1jj]
# ..                                         ...                     ...
# 643                                        NaN                [TRV1jj]
# 644                                        NaN                [TRV1jj]
#
#     ExptRes.result0.Mass (GeV) ExptRes.result0.AnalysisID  \
# 0               [(y1, 4700.0)]             CMS-EXO-19-012
# 1               [(y1, 4000.0)]             CMS-EXO-19-012
# ..                         ...                        ...
# 643             [(y1, 4800.0)]             CMS-EXO-19-012
# 644             [(y1, 4100.0)]             CMS-EXO-19-012
#
#      ExptRes.result0.DataSetID  ExptRes.result0.AnalysisSqrts (TeV)  \
# 0                          NaN                         1.300000e+01
# 1                          NaN                         1.300000e+01
# ..                         ...                                  ...
# 643                        NaN                         1.300000e+01
# 644                        NaN                         1.300000e+01
#
#      ExptRes.result0.lumi (fb-1) ExptRes.result0.dataType  ExptRes.result0.r  \
# 0                   1.370000e+02               upperLimit       5.088482e-01
# 1                   1.370000e+02               upperLimit       7.679907e-02
# ..                           ...                      ...                ...
# 643                 1.370000e+02               upperLimit       6.551453e-02
# 644                 1.370000e+02               upperLimit       2.439062e-02
#
#      ExptRes.result0.r_expected ExptRes.result0.Width (GeV)
# 0                           NaN              [(y1, 1026.4)]
# 1                           NaN              [(y1, 177.02)]
# ..                          ...                         ...
# 643                         NaN              [(y1, 239.83)]
# 644                         NaN              [(y1, 143.36)]
#
# [645 rows x 76 columns]

# %%
dataDF['xsec13TeV(fb).55'] *(3 *dataDF['BRs.y1.q,q'] + dataDF['BRs.y1.c,c'] + dataDF['BRs.y1.b,b'] )
# Out:
# 0     7.421450e+00
# 1     1.411697e+00
#           ...
# 643   3.895343e-01
# 644   3.265514e-01
# Length: 645, dtype: float64

# %%
dataDF['ExptRes.result0.theory prediction (fb)']
# Out:
# 0     7.421450e+00
# 1     1.411697e+00
#           ...
# 643   3.895343e-01
# 644   3.265514e-01
# Name: ExptRes.result0.theory prediction (fb), Length: 645, dtype: float64

# %%
(dataDF['xsec13TeV(fb).55'] *(3 *dataDF['BRs.y1.q,q'] + dataDF['BRs.y1.c,c'] + dataDF['BRs.y1.b,b'] ))/dataDF['ExptRes.result0.theory prediction (fb)']
# Out:
# 0     1.000000e+00
# 1     1.000000e+00
#           ...
# 643   1.000000e+00
# 644   1.000000e+00
# Length: 645, dtype: float64

# %%
mask = dataDF['ExptRes.result0.r'].isna()
rows_with_nan = dataDF[mask]
rows_with_nan
#print(rows_with_nan)
# Out:
#                           filename      mass.55  mass.5000001  mass.9000002  \
# 25   run_15_mzp_1800_gvq_0.94.slha 1.800000e+03  0.000000e+00  9.118760e+01
# 109  run_14_mzp_1800_gvq_0.63.slha 1.800000e+03  0.000000e+00  9.118760e+01
# 267  run_45_mzp_2000_gvq_0.94.slha 2.000000e+03  0.000000e+00  9.118760e+01
# 430  run_30_mzp_1900_gvq_0.94.slha 1.900000e+03  0.000000e+00  9.118760e+01
#
#      mass.9000003  mass.9000004     width.55  width.5000001  width.9000002  \
# 25   7.982436e+01  7.982436e+01 8.081958e+02   0.000000e+00   2.495200e+00
# 109  7.982436e+01  7.982436e+01 3.930641e+02   0.000000e+00   2.495200e+00
# 267  7.982436e+01  7.982436e+01 8.980200e+02   0.000000e+00   2.495200e+00
# 430  7.982436e+01  7.982436e+01 8.531088e+02   0.000000e+00   2.495200e+00
#
#      width.9000003  width.9000004     extpar.1     extpar.2     extpar.3  \
# 25    2.085000e+00   2.085000e+00 0.000000e+00 1.000000e+00 0.000000e+00
# 109   2.085000e+00   2.085000e+00 0.000000e+00 1.000000e+00 0.000000e+00
# 267   2.085000e+00   2.085000e+00 0.000000e+00 1.000000e+00 0.000000e+00
# 430   2.085000e+00   2.085000e+00 0.000000e+00 1.000000e+00 0.000000e+00
#
#         extpar.4     extpar.5     extpar.6     extpar.7     extpar.8  \
# 25  9.406900e-01 9.406900e-01 9.406900e-01 9.406900e-01 9.406900e-01
# 109 6.339000e-01 6.339000e-01 6.339000e-01 6.339000e-01 6.339000e-01
# 267 9.406900e-01 9.406900e-01 9.406900e-01 9.406900e-01 9.406900e-01
# 430 9.406900e-01 9.406900e-01 9.406900e-01 9.406900e-01 9.406900e-01
#
#         extpar.9    extpar.10    extpar.11    extpar.12    extpar.13  \
# 25  9.406900e-01 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 109 6.339000e-01 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 267 9.406900e-01 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 430 9.406900e-01 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
#
#        extpar.14    extpar.15    extpar.16  xsec13TeV(fb).55   BRs.y1.b,b  \
# 25  0.000000e+00 0.000000e+00 0.000000e+00      1.789300e+04 1.568336e-01
# 109 0.000000e+00 0.000000e+00 0.000000e+00      8.136900e+03 1.464336e-01
# 267 0.000000e+00 0.000000e+00 0.000000e+00      1.036800e+04 1.568293e-01
# 430 0.000000e+00 0.000000e+00 0.000000e+00      1.360300e+04 1.568312e-01
#
#       BRs.y1.c,c   BRs.y1.q,q  BRs.y1.t-,t+  BRs.y1.xd~,xd  \
# 25  1.568336e-01 1.568336e-01  1.567542e-01   5.907786e-02
# 109 1.464336e-01 1.464336e-01  1.463594e-01   1.214725e-01
# 267 1.568293e-01 1.568293e-01  1.567773e-01   5.907624e-02
# 430 1.568312e-01 1.568312e-01  1.567673e-01   5.907695e-02
#
#      totalxsec13TeV(fb)  totalxsec8TeV(fb)  \
# 25         1.789300e+04       0.000000e+00
# 109        8.136900e+03       0.000000e+00
# 267        1.036800e+04       0.000000e+00
# 430        1.360300e+04       0.000000e+00
#
#                                      SMS Decomposition  \
# 25   [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# 109  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# 267  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# 430  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
#
#      Total xsec for missing topologies (fb)  \
# 25                             3.861883e+03
# 109                            2.179321e+03
# 267                            2.237970e+03
# 430                            2.936129e+03
#
#      Total xsec for missing topologies with displaced decays (fb)  \
# 25                                        0.000000e+00
# 109                                       0.000000e+00
# 267                                       0.000000e+00
# 430                                       0.000000e+00
#
#      Total xsec for missing topologies with prompt decays (fb)  \
# 25                                        1.789300e+04
# 109                                       8.136899e+03
# 267                                       1.036800e+04
# 430                                       1.360300e+04
#
#      Total xsec for topologies outside the grid (fb)  OutputStatus.sigmacut  \
# 25                                      1.403112e+04           0.000000e+00
# 109                                     5.957578e+03           0.000000e+00
# 267                                     8.130031e+03           0.000000e+00
# 430                                     1.066687e+04           0.000000e+00
#
#      OutputStatus.minmassgap  OutputStatus.maxcond  OutputStatus.ncpus  \
# 25                         5          2.000000e-01                   1
# 109                        5          2.000000e-01                   1
# 267                        5          2.000000e-01                   1
# 430                        5          2.000000e-01                   1
#
#                                   OutputStatus.model  \
# 25   TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
# 109  TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
# 267  TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
# 430  TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
#
#      OutputStatus.promptwidth  OutputStatus.stablewidth  \
# 25               5.000000e+00              1.000000e-25
# 109              5.000000e+00              1.000000e-25
# 267              5.000000e+00              1.000000e-25
# 430              5.000000e+00              1.000000e-25
#
#     OutputStatus.eraseprompt  OutputStatus.checkinput  \
# 25          eCharge,colordim                     True
# 109         eCharge,colordim                     True
# 267         eCharge,colordim                     True
# 430         eCharge,colordim                     True
#
#      OutputStatus.doinvisible  OutputStatus.docompress  \
# 25                       True                     True
# 109                      True                     True
# 267                      True                     True
# 430                      True                     True
#
#      OutputStatus.computestatistics  OutputStatus.testcoverage  \
# 25                             True                       True
# 109                            True                       True
# 267                            True                       True
# 430                            True                       True
#
#      OutputStatus.combinesrs  OutputStatus.reportallsrs  \
# 25                     False                      False
# 109                    False                      False
# 267                    False                      False
# 430                    False                      False
#
#      OutputStatus.experimentalfeatures  OutputStatus.file status  \
# 25                               False                         1
# 109                              False                         1
# 267                              False                         1
# 430                              False                         1
#
#      OutputStatus.decomposition status OutputStatus.warnings  \
# 25                                   0         Input file ok
# 109                                  0         Input file ok
# 267                                  0         Input file ok
# 430                                  0         Input file ok
#
#                              OutputStatus.input file  \
# 25   TRV1jj_slha_broad/run_15_mzp_1800_gvq_0.94.slha
# 109  TRV1jj_slha_broad/run_14_mzp_1800_gvq_0.63.slha
# 267  TRV1jj_slha_broad/run_45_mzp_2000_gvq_0.94.slha
# 430  TRV1jj_slha_broad/run_30_mzp_1900_gvq_0.94.slha
#
#     OutputStatus.database version OutputStatus.smodels version  \
# 25                     3.0.0-beta                   3.0.0-beta
# 109                    3.0.0-beta                   3.0.0-beta
# 267                    3.0.0-beta                   3.0.0-beta
# 430                    3.0.0-beta                   3.0.0-beta
#
#      ExptRes.result0.maxcond  ExptRes.result0.theory prediction (fb)  \
# 25                       NaN                                     NaN
# 109                      NaN                                     NaN
# 267                      NaN                                     NaN
# 430                      NaN                                     NaN
#
#      ExptRes.result0.upper limit (fb)  \
# 25                                NaN
# 109                               NaN
# 267                               NaN
# 430                               NaN
#
#      ExptRes.result0.expected upper limit (fb) ExptRes.result0.TxNames  \
# 25                                         NaN                     NaN
# 109                                        NaN                     NaN
# 267                                        NaN                     NaN
# 430                                        NaN                     NaN
#
#     ExptRes.result0.Mass (GeV) ExptRes.result0.AnalysisID  \
# 25                         NaN                        NaN
# 109                        NaN                        NaN
# 267                        NaN                        NaN
# 430                        NaN                        NaN
#
#      ExptRes.result0.DataSetID  ExptRes.result0.AnalysisSqrts (TeV)  \
# 25                         NaN                                  NaN
# 109                        NaN                                  NaN
# 267                        NaN                                  NaN
# 430                        NaN                                  NaN
#
#      ExptRes.result0.lumi (fb-1) ExptRes.result0.dataType  ExptRes.result0.r  \
# 25                           NaN                      NaN                NaN
# 109                          NaN                      NaN                NaN
# 267                          NaN                      NaN                NaN
# 430                          NaN                      NaN                NaN
#
#      ExptRes.result0.r_expected ExptRes.result0.Width (GeV)
# 25                          NaN                         NaN
# 109                         NaN                         NaN
# 267                         NaN                         NaN
# 430                         NaN                         NaN

# %%
mask = dataDF['ExptRes.result0.r'].isna()
rows_with_nan = dataDF[mask]
rows_with_nan.to_csv('rows_with_nan_.csv', index=False)
rows_with_nan
# Out:
#                           filename      mass.55  mass.5000001  mass.9000002  \
# 25   run_15_mzp_1800_gvq_0.94.slha 1.800000e+03  0.000000e+00  9.118760e+01
# 109  run_14_mzp_1800_gvq_0.63.slha 1.800000e+03  0.000000e+00  9.118760e+01
# 267  run_45_mzp_2000_gvq_0.94.slha 2.000000e+03  0.000000e+00  9.118760e+01
# 430  run_30_mzp_1900_gvq_0.94.slha 1.900000e+03  0.000000e+00  9.118760e+01
#
#      mass.9000003  mass.9000004     width.55  width.5000001  width.9000002  \
# 25   7.982436e+01  7.982436e+01 8.081958e+02   0.000000e+00   2.495200e+00
# 109  7.982436e+01  7.982436e+01 3.930641e+02   0.000000e+00   2.495200e+00
# 267  7.982436e+01  7.982436e+01 8.980200e+02   0.000000e+00   2.495200e+00
# 430  7.982436e+01  7.982436e+01 8.531088e+02   0.000000e+00   2.495200e+00
#
#      width.9000003  width.9000004     extpar.1     extpar.2     extpar.3  \
# 25    2.085000e+00   2.085000e+00 0.000000e+00 1.000000e+00 0.000000e+00
# 109   2.085000e+00   2.085000e+00 0.000000e+00 1.000000e+00 0.000000e+00
# 267   2.085000e+00   2.085000e+00 0.000000e+00 1.000000e+00 0.000000e+00
# 430   2.085000e+00   2.085000e+00 0.000000e+00 1.000000e+00 0.000000e+00
#
#         extpar.4     extpar.5     extpar.6     extpar.7     extpar.8  \
# 25  9.406900e-01 9.406900e-01 9.406900e-01 9.406900e-01 9.406900e-01
# 109 6.339000e-01 6.339000e-01 6.339000e-01 6.339000e-01 6.339000e-01
# 267 9.406900e-01 9.406900e-01 9.406900e-01 9.406900e-01 9.406900e-01
# 430 9.406900e-01 9.406900e-01 9.406900e-01 9.406900e-01 9.406900e-01
#
#         extpar.9    extpar.10    extpar.11    extpar.12    extpar.13  \
# 25  9.406900e-01 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 109 6.339000e-01 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 267 9.406900e-01 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
# 430 9.406900e-01 0.000000e+00 0.000000e+00 0.000000e+00 0.000000e+00
#
#        extpar.14    extpar.15    extpar.16  xsec13TeV(fb).55   BRs.y1.b,b  \
# 25  0.000000e+00 0.000000e+00 0.000000e+00      1.789300e+04 1.568336e-01
# 109 0.000000e+00 0.000000e+00 0.000000e+00      8.136900e+03 1.464336e-01
# 267 0.000000e+00 0.000000e+00 0.000000e+00      1.036800e+04 1.568293e-01
# 430 0.000000e+00 0.000000e+00 0.000000e+00      1.360300e+04 1.568312e-01
#
#       BRs.y1.c,c   BRs.y1.q,q  BRs.y1.t-,t+  BRs.y1.xd~,xd  \
# 25  1.568336e-01 1.568336e-01  1.567542e-01   5.907786e-02
# 109 1.464336e-01 1.464336e-01  1.463594e-01   1.214725e-01
# 267 1.568293e-01 1.568293e-01  1.567773e-01   5.907624e-02
# 430 1.568312e-01 1.568312e-01  1.567673e-01   5.907695e-02
#
#      totalxsec13TeV(fb)  totalxsec8TeV(fb)  \
# 25         1.789300e+04       0.000000e+00
# 109        8.136900e+03       0.000000e+00
# 267        1.036800e+04       0.000000e+00
# 430        1.360300e+04       0.000000e+00
#
#                                      SMS Decomposition  \
# 25   [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# 109  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# 267  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
# 430  [{'ID': 1, 'SMS': '(PV > inv)', 'Masses (GeV)'...
#
#      Total xsec for missing topologies (fb)  \
# 25                             3.861883e+03
# 109                            2.179321e+03
# 267                            2.237970e+03
# 430                            2.936129e+03
#
#      Total xsec for missing topologies with displaced decays (fb)  \
# 25                                        0.000000e+00
# 109                                       0.000000e+00
# 267                                       0.000000e+00
# 430                                       0.000000e+00
#
#      Total xsec for missing topologies with prompt decays (fb)  \
# 25                                        1.789300e+04
# 109                                       8.136899e+03
# 267                                       1.036800e+04
# 430                                       1.360300e+04
#
#      Total xsec for topologies outside the grid (fb)  OutputStatus.sigmacut  \
# 25                                      1.403112e+04           0.000000e+00
# 109                                     5.957578e+03           0.000000e+00
# 267                                     8.130031e+03           0.000000e+00
# 430                                     1.066687e+04           0.000000e+00
#
#      OutputStatus.minmassgap  OutputStatus.maxcond  OutputStatus.ncpus  \
# 25                         5          2.000000e-01                   1
# 109                        5          2.000000e-01                   1
# 267                        5          2.000000e-01                   1
# 430                        5          2.000000e-01                   1
#
#                                   OutputStatus.model  \
# 25   TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
# 109  TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
# 267  TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
# 430  TRV1jj_slha_broad/run_01_mzp_1800_gvq_0.13.slha
#
#      OutputStatus.promptwidth  OutputStatus.stablewidth  \
# 25               5.000000e+00              1.000000e-25
# 109              5.000000e+00              1.000000e-25
# 267              5.000000e+00              1.000000e-25
# 430              5.000000e+00              1.000000e-25
#
#     OutputStatus.eraseprompt  OutputStatus.checkinput  \
# 25          eCharge,colordim                     True
# 109         eCharge,colordim                     True
# 267         eCharge,colordim                     True
# 430         eCharge,colordim                     True
#
#      OutputStatus.doinvisible  OutputStatus.docompress  \
# 25                       True                     True
# 109                      True                     True
# 267                      True                     True
# 430                      True                     True
#
#      OutputStatus.computestatistics  OutputStatus.testcoverage  \
# 25                             True                       True
# 109                            True                       True
# 267                            True                       True
# 430                            True                       True
#
#      OutputStatus.combinesrs  OutputStatus.reportallsrs  \
# 25                     False                      False
# 109                    False                      False
# 267                    False                      False
# 430                    False                      False
#
#      OutputStatus.experimentalfeatures  OutputStatus.file status  \
# 25                               False                         1
# 109                              False                         1
# 267                              False                         1
# 430                              False                         1
#
#      OutputStatus.decomposition status OutputStatus.warnings  \
# 25                                   0         Input file ok
# 109                                  0         Input file ok
# 267                                  0         Input file ok
# 430                                  0         Input file ok
#
#                              OutputStatus.input file  \
# 25   TRV1jj_slha_broad/run_15_mzp_1800_gvq_0.94.slha
# 109  TRV1jj_slha_broad/run_14_mzp_1800_gvq_0.63.slha
# 267  TRV1jj_slha_broad/run_45_mzp_2000_gvq_0.94.slha
# 430  TRV1jj_slha_broad/run_30_mzp_1900_gvq_0.94.slha
#
#     OutputStatus.database version OutputStatus.smodels version  \
# 25                     3.0.0-beta                   3.0.0-beta
# 109                    3.0.0-beta                   3.0.0-beta
# 267                    3.0.0-beta                   3.0.0-beta
# 430                    3.0.0-beta                   3.0.0-beta
#
#      ExptRes.result0.maxcond  ExptRes.result0.theory prediction (fb)  \
# 25                       NaN                                     NaN
# 109                      NaN                                     NaN
# 267                      NaN                                     NaN
# 430                      NaN                                     NaN
#
#      ExptRes.result0.upper limit (fb)  \
# 25                                NaN
# 109                               NaN
# 267                               NaN
# 430                               NaN
#
#      ExptRes.result0.expected upper limit (fb) ExptRes.result0.TxNames  \
# 25                                         NaN                     NaN
# 109                                        NaN                     NaN
# 267                                        NaN                     NaN
# 430                                        NaN                     NaN
#
#     ExptRes.result0.Mass (GeV) ExptRes.result0.AnalysisID  \
# 25                         NaN                        NaN
# 109                        NaN                        NaN
# 267                        NaN                        NaN
# 430                        NaN                        NaN
#
#      ExptRes.result0.DataSetID  ExptRes.result0.AnalysisSqrts (TeV)  \
# 25                         NaN                                  NaN
# 109                        NaN                                  NaN
# 267                        NaN                                  NaN
# 430                        NaN                                  NaN
#
#      ExptRes.result0.lumi (fb-1) ExptRes.result0.dataType  ExptRes.result0.r  \
# 25                           NaN                      NaN                NaN
# 109                          NaN                      NaN                NaN
# 267                          NaN                      NaN                NaN
# 430                          NaN                      NaN                NaN
#
#      ExptRes.result0.r_expected ExptRes.result0.Width (GeV)
# 25                          NaN                         NaN
# 109                         NaN                         NaN
# 267                         NaN                         NaN
# 430                         NaN                         NaN

# %% [raw]
# Pt = 30  # > 30 GeV
# Delta_eta = 1.3 #|eta1 - eta2| <1.3
# mij =  2*Pt*np.cosh(Delta_eta/2) #mij > 2*Pt*np.cosh(Delta_eta/2)
# mij
